# %%
import numpy as np
import cv2
import time
from mss import mss
from PIL import Image
import pyscreenshot
from PIL import ImageGrab
import pyautogui
from matplotlib import pyplot as plt
import glob
from skimage.metrics import structural_similarity
import os
import smtplib
import imghdr
from email.message import EmailMessage

# %%
def screenshot_base():
    #Screenshot
    pic = pyscreenshot.grab(bbox=(239, 364, 1427, 940))
    pic.save(r"C:\Users\55619\Desktop\Python Banco de Dados\Screenshot Base.png")

# %%
def crop():
    Positions = [[2,0,222,222],
                [242,0,462,222],
                [482,0,702,222],
                [722,0,942,222],
                [962,0,1182,222],
                [2,350,222,572], 
                [242,350,462,572], 
                [482,350,702,572],
                [722,350,942,572],
                [962,350,1182,572]]
                
    
    
    for i in Positions:
        left = i[0]
        top = i[1]
        right = i[2]
        bottom = i[3]
        
        im = Image.open(r"C:\Users\55619\Desktop\Python Banco de Dados\Screenshot Base.png")
        
        counter = 0
        filename = r"C:\Users\55619\Desktop\Python Banco de Dados\Crop{}.png"
        while os.path.isfile(filename.format(counter)):
            counter += 1
        filename = filename.format(counter)

    # Cropped image of above dimension
    # (It will not change original image
        im1 = im.crop((left, top, right, bottom))
        if match(im1) == False:
            im1.save(filename)
            achar(filename)
        else:
            print("Já existe no banco")

# %%
def firstcrop():
    Positions = [[2,0,222,222],
                [242,0,462,222],
                [482,0,702,222],
                [722,0,942,222],
                [962,0,1182,222],
                [2,350,222,572], 
                [242,350,462,572], 
                [482,350,702,572],
                [722,350,942,572],
                [962,350,1182,572]]
                
    
    
    for i in Positions:
        left = i[0]
        top = i[1]
        right = i[2]
        bottom = i[3]
        
        im = Image.open(r"C:\Users\55619\Desktop\Python Banco de Dados\Screenshot Base.png")
        
        counter = 0
        filename = r"C:\Users\55619\Desktop\Python Banco de Dados\Crop{}.png"
        while os.path.isfile(filename.format(counter)):
            counter += 1
        filename = filename.format(counter)

    # Cropped image of above dimension
    # (It will not change original image
        im1 = im.crop((left, top, right, bottom))
        im1.save(filename)

# %%
def orb_sim(img1, img2):
  # SIFT is no longer available in cv2 so using ORB
  orb = cv2.ORB_create()

  # detect keypoints and descriptors
  kp_a, desc_a = orb.detectAndCompute(img1, None)
  kp_b, desc_b = orb.detectAndCompute(img2, None)

  # define the bruteforce matcher object
  bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    
  #perform matches. 
  matches = bf.match(desc_a, desc_b)
  #Look for similar regions with distance < 50. Goes from 0 to 100 so pick a number between.
  similar_regions = [i for i in matches if i.distance < 50]  
  if len(matches) == 0:
    return 0
  return len(similar_regions) / len(matches)

# %%
def structural_sim(img1, img2):

  sim, diff = structural_similarity(img1, img2, full=True)
  return sim

# %%
def match(img):
  achou = 0
  for f in glob.iglob(r'C:\Users\55619\Desktop\Python Banco de Dados\Crop*.png'):
    image = cv2.imread(f, 0)
    img = np.array(img)
    orb_similarity = orb_sim(img, image)  #1.0 means identical. Lower = not similar
    print("Similarity using ORB is: " + str(orb_similarity) + "\n")
    if orb_similarity > 0.7:
      print('Mesmo item encontrado')
      print(f)
      achou += 1
    else:
      print("Novo Item")
  if achou > 0:
    return True
  else:
    return False

# %%
def achar(filename):
    r = None
    while r is None:
        try:
            print('procurando bolsa')
            bolsa = pyautogui.locateOnScreen(filename)
            if bolsa is None:
                break
            else:
                pyautogui.keyDown('ctrl')
                pyautogui.click(filename)
                pyautogui.keyUp('ctrl')
                pyautogui.click(369, 18)
                euqueroreservar()
                r = 1
                
        except Exception as e:
            r = None
            break

# %%
def euqueroreservar():
    t = None
    while t is None:
        try:
            print('procurando eu quero')
            botaoeuquero = pyautogui.locateOnScreen(r'C:\Users\55619\Desktop\Python Banco de Dados\Autogui\euquero.png')
            if botaoeuquero is None:
                print('não achou botao eu quero')
                botaooutrapessoa = pyautogui.locateOnScreen(r'C:\Users\55619\Desktop\Python Banco de Dados\Autogui\outrapessoa.png')
                if botaooutrapessoa is not None:
                    print('Reservado por outra pessoa')
                    pyautogui.keyDown('ctrl')
                    pyautogui.press('w')
                    pyautogui.keyUp('ctrl')
                    break
                    
            else:
                pyautogui.click(r'C:\Users\55619\Desktop\Python Banco de Dados\Autogui\euquero.png')
                z = None
                while z is None:
                    try:
                        print('procurando continuar')
                        botaocontinuar = pyautogui.locateOnScreen(r'C:\Users\55619\Desktop\Python Banco de Dados\Autogui\continuar.png')
                        if botaocontinuar is not None:
                            pyautogui.click(r'C:\Users\55619\Desktop\Python Banco de Dados\Autogui\continuar.png')
                            pyautogui.moveTo(369, 18)
                            pyautogui.mouseDown()
                            pyautogui.moveTo(363, 86)
                            pyautogui.mouseUp()
                            pyautogui.click(124, 17)
                            t = 1
                            z = 1
                    except Exception as u:
                        z = None
                        break
                
        except Exception as y:
            t = None
            break

# %%
def enviaremail(filename):
    EMAIL_ADRESS = 'koolthest@gmail.com'
    EMAIL_PASSWORD = 'urztexbslgvxlxpa'

    msg = EmailMessage()
    msg['Subject'] = 'Produto novo reservado <3'
    msg['From'] = EMAIL_ADRESS
    msg['To'] = 'uclosetbrecho@gmail.com'

    with open(filename, 'rb') as f:
        file_data = f.read()
        file_type = imghdr.what(f.name)
        file_name = f.name
            
    msg.add_attachment(file_data, maintype = 'image', subtype = file_type, filename = file_name)

    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
        smtp.login(EMAIL_ADRESS, EMAIL_PASSWORD)
        smtp.send_message(msg)

# %%
def main():
    while(True):
        screenshot_base()
        crop()
        pyautogui.press('f5')
        time.sleep(1)

# %%
screenshot_base()
firstcrop()

# %%
pyautogui.click(1446, 208)
main()
# Out:
# Similarity using ORB is: 0.17333333333333334
#
# Novo Item
# Similarity using ORB is: 1.0
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop1.png
# Similarity using ORB is: 0.09433962264150944
#
# Novo Item
# Similarity using ORB is: 0.03669724770642202
#
# Novo Item
# Similarity using ORB is: 0.1111111111111111
#
# Novo Item
# Similarity using ORB is: 0.08602150537634409
#
# Novo Item
# Similarity using ORB is: 0.02857142857142857
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.14432989690721648
#
# Novo Item
# Similarity using ORB is: 0.07291666666666667
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.125
#
# Novo Item
# Similarity using ORB is: 0.016666666666666666
#
# Novo Item
# Similarity using ORB is: 0.008333333333333333
#
# Novo Item
# Similarity using ORB is: 0.9918032786885246
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop2.png
# Similarity using ORB is: 0.017094017094017096
#
# Novo Item
# Similarity using ORB is: 0.024390243902439025
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0196078431372549
#
# Novo Item
# Similarity using ORB is: 0.008849557522123894
#
# Novo Item
# Similarity using ORB is: 0.015873015873015872
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.1864406779661017
#
# Novo Item
# Similarity using ORB is: 0.10784313725490197
#
# Novo Item
# Similarity using ORB is: 0.09375
#
# Novo Item
# Similarity using ORB is: 0.01904761904761905
#
# Novo Item
# Similarity using ORB is: 0.9970238095238095
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop3.png
# Similarity using ORB is: 0.06451612903225806
#
# Novo Item
# Similarity using ORB is: 0.009174311926605505
#
# Novo Item
# Similarity using ORB is: 0.02127659574468085
#
# Novo Item
# Similarity using ORB is: 0.16666666666666666
#
# Novo Item
# Similarity using ORB is: 0.05
#
# Novo Item
# Similarity using ORB is: 0.018518518518518517
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.12280701754385964
#
# Novo Item
# Similarity using ORB is: 0.06741573033707865
#
# Novo Item
# Similarity using ORB is: 0.04819277108433735
#
# Novo Item
# Similarity using ORB is: 0.046511627906976744
#
# Novo Item
# Similarity using ORB is: 0.09302325581395349
#
# Novo Item
# Similarity using ORB is: 1.0
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop4.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.027777777777777776
#
# Novo Item
# Similarity using ORB is: 0.08974358974358974
#
# Novo Item
# Similarity using ORB is: 0.04878048780487805
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.11578947368421053
#
# Novo Item
# Similarity using ORB is: 0.03571428571428571
#
# Novo Item
# Similarity using ORB is: 0.01639344262295082
#
# Novo Item
# Similarity using ORB is: 0.0380952380952381
#
# Novo Item
# Similarity using ORB is: 0.02
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.9945652173913043
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop5.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.01904761904761905
#
# Novo Item
# Similarity using ORB is: 0.00909090909090909
#
# Novo Item
# Similarity using ORB is: 0.01694915254237288
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.010101010101010102
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.008771929824561403
#
# Novo Item
# Similarity using ORB is: 0.022988505747126436
#
# Novo Item
# Similarity using ORB is: 0.008771929824561403
#
# Novo Item
# Similarity using ORB is: 0.9064516129032258
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop6.png
# Similarity using ORB is: 0.02040816326530612
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.039473684210526314
#
# Novo Item
# Similarity using ORB is: 0.1590909090909091
#
# Novo Item
# Similarity using ORB is: 0.06315789473684211
#
# Novo Item
# Similarity using ORB is: 0.00847457627118644
#
# Novo Item
# Similarity using ORB is: 0.13
#
# Novo Item
# Similarity using ORB is: 0.06329113924050633
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.009174311926605505
#
# Novo Item
# Similarity using ORB is: 0.9451219512195121
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop7.png
# Similarity using ORB is: 0.06422018348623854
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.013333333333333334
#
# Novo Item
# Similarity using ORB is: 0.042105263157894736
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.037037037037037035
#
# Novo Item
# Similarity using ORB is: 0.06944444444444445
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.008333333333333333
#
# Novo Item
# Similarity using ORB is: 0.03389830508474576
#
# Novo Item
# Similarity using ORB is: 0.9826086956521739
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop8.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.05660377358490566
#
# Novo Item
# Similarity using ORB is: 0.017241379310344827
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.864406779661017
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop9.png
# Já existe no banco
# Similarity using ORB is: 0.06172839506172839
#
# Novo Item
# Similarity using ORB is: 0.07920792079207921
#
# Novo Item
# Similarity using ORB is: 0.9937694704049844
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop10.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.1188118811881188
#
# Novo Item
# Similarity using ORB is: 0.03896103896103896
#
# Novo Item
# Similarity using ORB is: 0.05
#
# Novo Item
# Similarity using ORB is: 0.018867924528301886
#
# Novo Item
# Similarity using ORB is: 0.08571428571428572
#
# Novo Item
# Similarity using ORB is: 0.016129032258064516
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.17333333333333334
#
# Novo Item
# Similarity using ORB is: 1.0
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop1.png
# Similarity using ORB is: 0.09433962264150944
#
# Novo Item
# Similarity using ORB is: 0.03669724770642202
#
# Novo Item
# Similarity using ORB is: 0.1111111111111111
#
# Novo Item
# Similarity using ORB is: 0.08602150537634409
#
# Novo Item
# Similarity using ORB is: 0.02857142857142857
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.14432989690721648
#
# Novo Item
# Similarity using ORB is: 0.07291666666666667
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.125
#
# Novo Item
# Similarity using ORB is: 0.016666666666666666
#
# Novo Item
# Similarity using ORB is: 0.008333333333333333
#
# Novo Item
# Similarity using ORB is: 0.9918032786885246
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop2.png
# Similarity using ORB is: 0.017094017094017096
#
# Novo Item
# Similarity using ORB is: 0.024390243902439025
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0196078431372549
#
# Novo Item
# Similarity using ORB is: 0.008849557522123894
#
# Novo Item
# Similarity using ORB is: 0.015873015873015872
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.1864406779661017
#
# Novo Item
# Similarity using ORB is: 0.10784313725490197
#
# Novo Item
# Similarity using ORB is: 0.09375
#
# Novo Item
# Similarity using ORB is: 0.01904761904761905
#
# Novo Item
# Similarity using ORB is: 0.9970238095238095
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop3.png
# Similarity using ORB is: 0.06451612903225806
#
# Novo Item
# Similarity using ORB is: 0.009174311926605505
#
# Novo Item
# Similarity using ORB is: 0.02127659574468085
#
# Novo Item
# Similarity using ORB is: 0.16666666666666666
#
# Novo Item
# Similarity using ORB is: 0.05
#
# Novo Item
# Similarity using ORB is: 0.018518518518518517
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.12280701754385964
#
# Novo Item
# Similarity using ORB is: 0.06741573033707865
#
# Novo Item
# Similarity using ORB is: 0.04819277108433735
#
# Novo Item
# Similarity using ORB is: 0.046511627906976744
#
# Novo Item
# Similarity using ORB is: 0.09302325581395349
#
# Novo Item
# Similarity using ORB is: 1.0
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop4.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.027777777777777776
#
# Novo Item
# Similarity using ORB is: 0.08974358974358974
#
# Novo Item
# Similarity using ORB is: 0.04878048780487805
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.11578947368421053
#
# Novo Item
# Similarity using ORB is: 0.03571428571428571
#
# Novo Item
# Similarity using ORB is: 0.01639344262295082
#
# Novo Item
# Similarity using ORB is: 0.0380952380952381
#
# Novo Item
# Similarity using ORB is: 0.02
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.9945652173913043
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop5.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.01904761904761905
#
# Novo Item
# Similarity using ORB is: 0.00909090909090909
#
# Novo Item
# Similarity using ORB is: 0.01694915254237288
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.010101010101010102
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.008771929824561403
#
# Novo Item
# Similarity using ORB is: 0.022988505747126436
#
# Novo Item
# Similarity using ORB is: 0.008771929824561403
#
# Novo Item
# Similarity using ORB is: 0.9064516129032258
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop6.png
# Similarity using ORB is: 0.02040816326530612
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.039473684210526314
#
# Novo Item
# Similarity using ORB is: 0.1590909090909091
#
# Novo Item
# Similarity using ORB is: 0.06315789473684211
#
# Novo Item
# Similarity using ORB is: 0.00847457627118644
#
# Novo Item
# Similarity using ORB is: 0.13
#
# Novo Item
# Similarity using ORB is: 0.06329113924050633
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.009174311926605505
#
# Novo Item
# Similarity using ORB is: 0.9451219512195121
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop7.png
# Similarity using ORB is: 0.06422018348623854
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.013333333333333334
#
# Novo Item
# Similarity using ORB is: 0.042105263157894736
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.037037037037037035
#
# Novo Item
# Similarity using ORB is: 0.06944444444444445
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.008333333333333333
#
# Novo Item
# Similarity using ORB is: 0.03389830508474576
#
# Novo Item
# Similarity using ORB is: 0.9826086956521739
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop8.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.05660377358490566
#
# Novo Item
# Similarity using ORB is: 0.017241379310344827
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.864406779661017
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop9.png
# Já existe no banco
# Similarity using ORB is: 0.06172839506172839
#
# Novo Item
# Similarity using ORB is: 0.07920792079207921
#
# Novo Item
# Similarity using ORB is: 0.9937694704049844
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop10.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.1188118811881188
#
# Novo Item
# Similarity using ORB is: 0.03896103896103896
#
# Novo Item
# Similarity using ORB is: 0.05
#
# Novo Item
# Similarity using ORB is: 0.018867924528301886
#
# Novo Item
# Similarity using ORB is: 0.08571428571428572
#
# Novo Item
# Similarity using ORB is: 0.016129032258064516
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.17333333333333334
#
# Novo Item
# Similarity using ORB is: 1.0
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop1.png
# Similarity using ORB is: 0.09433962264150944
#
# Novo Item
# Similarity using ORB is: 0.03669724770642202
#
# Novo Item
# Similarity using ORB is: 0.1111111111111111
#
# Novo Item
# Similarity using ORB is: 0.08602150537634409
#
# Novo Item
# Similarity using ORB is: 0.02857142857142857
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.14432989690721648
#
# Novo Item
# Similarity using ORB is: 0.07291666666666667
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.125
#
# Novo Item
# Similarity using ORB is: 0.016666666666666666
#
# Novo Item
# Similarity using ORB is: 0.008333333333333333
#
# Novo Item
# Similarity using ORB is: 0.9918032786885246
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop2.png
# Similarity using ORB is: 0.017094017094017096
#
# Novo Item
# Similarity using ORB is: 0.024390243902439025
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0196078431372549
#
# Novo Item
# Similarity using ORB is: 0.008849557522123894
#
# Novo Item
# Similarity using ORB is: 0.015873015873015872
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.1864406779661017
#
# Novo Item
# Similarity using ORB is: 0.10784313725490197
#
# Novo Item
# Similarity using ORB is: 0.09375
#
# Novo Item
# Similarity using ORB is: 0.01904761904761905
#
# Novo Item
# Similarity using ORB is: 0.9970238095238095
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop3.png
# Similarity using ORB is: 0.06451612903225806
#
# Novo Item
# Similarity using ORB is: 0.009174311926605505
#
# Novo Item
# Similarity using ORB is: 0.02127659574468085
#
# Novo Item
# Similarity using ORB is: 0.16666666666666666
#
# Novo Item
# Similarity using ORB is: 0.05
#
# Novo Item
# Similarity using ORB is: 0.018518518518518517
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.12280701754385964
#
# Novo Item
# Similarity using ORB is: 0.06741573033707865
#
# Novo Item
# Similarity using ORB is: 0.04819277108433735
#
# Novo Item
# Similarity using ORB is: 0.046511627906976744
#
# Novo Item
# Similarity using ORB is: 0.09302325581395349
#
# Novo Item
# Similarity using ORB is: 1.0
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop4.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.027777777777777776
#
# Novo Item
# Similarity using ORB is: 0.08974358974358974
#
# Novo Item
# Similarity using ORB is: 0.04878048780487805
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.11578947368421053
#
# Novo Item
# Similarity using ORB is: 0.03571428571428571
#
# Novo Item
# Similarity using ORB is: 0.01639344262295082
#
# Novo Item
# Similarity using ORB is: 0.0380952380952381
#
# Novo Item
# Similarity using ORB is: 0.02
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.9945652173913043
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop5.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.01904761904761905
#
# Novo Item
# Similarity using ORB is: 0.00909090909090909
#
# Novo Item
# Similarity using ORB is: 0.01694915254237288
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.010101010101010102
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.008771929824561403
#
# Novo Item
# Similarity using ORB is: 0.022988505747126436
#
# Novo Item
# Similarity using ORB is: 0.008771929824561403
#
# Novo Item
# Similarity using ORB is: 0.9064516129032258
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop6.png
# Similarity using ORB is: 0.02040816326530612
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.039473684210526314
#
# Novo Item
# Similarity using ORB is: 0.1590909090909091
#
# Novo Item
# Similarity using ORB is: 0.06315789473684211
#
# Novo Item
# Similarity using ORB is: 0.00847457627118644
#
# Novo Item
# Similarity using ORB is: 0.13
#
# Novo Item
# Similarity using ORB is: 0.06329113924050633
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.009174311926605505
#
# Novo Item
# Similarity using ORB is: 0.9451219512195121
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop7.png
# Similarity using ORB is: 0.06422018348623854
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.013333333333333334
#
# Novo Item
# Similarity using ORB is: 0.042105263157894736
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.037037037037037035
#
# Novo Item
# Similarity using ORB is: 0.06944444444444445
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.008333333333333333
#
# Novo Item
# Similarity using ORB is: 0.03389830508474576
#
# Novo Item
# Similarity using ORB is: 0.9826086956521739
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop8.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# Similarity using ORB is: 0.05660377358490566
#
# Novo Item
# Similarity using ORB is: 0.017241379310344827
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.864406779661017
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop9.png
# Já existe no banco
# Similarity using ORB is: 0.06172839506172839
#
# Novo Item
# Similarity using ORB is: 0.07920792079207921
#
# Novo Item
# Similarity using ORB is: 0.9937694704049844
#
# Mesmo item encontrado
# C:\Users\55619\Desktop\Python Banco de Dados\Crop10.png
# Similarity using ORB is: 0.0
#
# Novo Item
# Similarity using ORB is: 0.1188118811881188
#
# Novo Item
# Similarity using ORB is: 0.03896103896103896
#
# Novo Item
# Similarity using ORB is: 0.05
#
# Novo Item
# Similarity using ORB is: 0.018867924528301886
#
# Novo Item
# Similarity using ORB is: 0.08571428571428572
#
# Novo Item
# Similarity using ORB is: 0.016129032258064516
#
# Novo Item
# Similarity using ORB is: 0.0
#
# Novo Item
# Já existe no banco
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2792\1473531199.py in <module>
#       1 pyautogui.click(1446, 208)
# ----> 2 main()
#
# ~\AppData\Local\Temp\ipykernel_2792\3120024397.py in main()
#       1 def main():
#       2     while(True):
# ----> 3         screenshot_base()
#       4         crop()
#       5         pyautogui.press('f5')
#
# ~\AppData\Local\Temp\ipykernel_2792\2626242889.py in screenshot_base()
#       1 def screenshot_base():
#       2     #Screenshot
# ----> 3     pic = pyscreenshot.grab(bbox=(239, 364, 1427, 940))
#       4     pic.save(r"C:\Users\55619\Desktop\Python Banco de Dados\Screenshot Base.png")
#
# c:\Users\55619\anaconda3\lib\site-packages\pyscreenshot\__init__.py in grab(bbox, childprocess, backend)
#      35         if y2 <= y1:
#      36             raise ValueError("bbox y2<=y1")
# ---> 37     return backend_grab(backend, bbox, childprocess)
#      38
#      39
#
# c:\Users\55619\anaconda3\lib\site-packages\pyscreenshot\loader.py in backend_grab(backend, bbox, childprocess)
#     169         return force(backend, bbox, childprocess)
#     170     else:
# --> 171         return auto(bbox, childprocess)
#     172
#     173
#
# c:\Users\55619\anaconda3\lib\site-packages\pyscreenshot\loader.py in auto(bbox, childprocess)
#     138             if select_childprocess(childprocess, backend_class):
#     139                 log.debug('running "%s" in child process', backend_name)
# --> 140                 im = childprocess_grab(backend_name, bbox)
#     141             else:
#     142                 obj = backend_class()
#
# c:\Users\55619\anaconda3\lib\site-packages\pyscreenshot\childproc.py in childprocess_grab(backend, bbox)
#      32             cmd += ["--debug"]
#      33
# ---> 34         p = run_mod_as_subproc("pyscreenshot.cli.grab", cmd)
#      35         if p.return_code != 0:
#      36             # log.debug(p)
#
# c:\Users\55619\anaconda3\lib\site-packages\pyscreenshot\util.py in run_mod_as_subproc(name, params)
#      50     python = sys.executable
#      51     cmd = [python, "-m", name] + params
# ---> 52     p = EasyProcess(cmd).call()
#      53     return p
#
# c:\Users\55619\anaconda3\lib\site-packages\easyprocess\__init__.py in call(self, timeout)
#     145         """
#     146         try:
# --> 147             self.start().wait(timeout=timeout)
#     148         finally:
#     149             if self.is_alive():
#
# c:\Users\55619\anaconda3\lib\site-packages\easyprocess\__init__.py in wait(self, timeout)
#     215         # Timeout (threading) discussion: https://stackoverflow.com/questions/1191374/subprocess-with-timeout
#     216
# --> 217         self._wait4process(timeout)
#     218
#     219         # if timeout is not None:
#
# c:\Users\55619\anaconda3\lib\site-packages\easyprocess\__init__.py in _wait4process(self, timeout)
#     241         if self.use_temp_files:
#     242             try:
# --> 243                 self.popen.wait(timeout=timeout)
#     244             except subprocess.TimeoutExpired:
#     245                 self.timeout_happened = True
#
# c:\Users\55619\anaconda3\lib\subprocess.py in wait(self, timeout)
#    1187             endtime = _time() + timeout
#    1188         try:
# -> 1189             return self._wait(timeout=timeout)
#    1190         except KeyboardInterrupt:
#    1191             # https://bugs.python.org/issue25942
#
# c:\Users\55619\anaconda3\lib\subprocess.py in _wait(self, timeout)
#    1468             if self.returncode is None:
#    1469                 # API note: Returns immediately if timeout_millis == 0.
# -> 1470                 result = _winapi.WaitForSingleObject(self._handle,
#    1471                                                      timeout_millis)
#    1472                 if result == _winapi.WAIT_TIMEOUT:
#
# KeyboardInterrupt:
